# %% [markdown]
# ## Job Satisfaction for dvelopers:
#
# Stackoverflow, one of the largest online communities for developers, has been conducting surveys on developers every year since 2010, targeting a variety of questions. In this article, I will focus on job satisfaction for developers in the developer survey of 2018 and try to extract insights into this matter. The data for this was taken from Kaggle datasets.

# %%
import pandas as pd
import itertools
import numpy as np
import pandas as pd
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from plotly import tools
init_notebook_mode(connected=True)  
from plotly.tools import FigureFactory as ff
import pycountry
import random
import squarify
from collections import Counter
import warnings
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# Auxilary functions
def remove_coma(val):
    value = val.replace(",","")
    return value

def get_merged_catColumns(df,col1,col2,colcounter,col1sorter = None, col2sorter = None):
    
    tempdf = df.copy()
    if col1sorter:
        tempdf[col1] = tempdf[col1].astype("category")
        tempdf[col1] = tempdf[col1].cat.set_categories(col1sorter)
        tempdf = tempdf.sort_values(by=col1,ascending=False)
    if col2sorter:
        tempdf[col2] = tempdf[col2].astype("category")
        tempdf[col2] = tempdf[col2].cat.set_categories(col2sorter)
        tempdf = tempdf.sort_values(by=col2,ascending=False)
    
    gp = tempdf.groupby([col1,col2])[colcounter].agg(["count"]).reset_index()
    g2 = tempdf[tempdf[col2].notnull()].groupby(col1)[colcounter].agg(["count"]).reset_index()
    merged = pd.merge(gp,g2,on=col1, how = "left")
    merged["percentage"] =  (merged["count_x"]/merged["count_y"]) * 100
    gp = merged.groupby([col1,col2])["percentage"].sum()
    return gp


def random_colors(number_of_colors):
    color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
                 for i in range(number_of_colors)]
    return color



def graph(datacolumns,type_of_graph, top = 0, title = None):
    data_frame = datacolumns.value_counts()
    layout = go.Layout()
    
    if type_of_graph == 'gpbarv':
        data = [go.Bar(
                x=datacolumns.index,
                y=datacolumns.values,
                marker=dict(color=random_colors(10), line=dict(color='rgb(8,48,107)',width=1.5,)),
                opacity = 0.6
        )]  

    elif type_of_graph == 'group':
        data = []
        marker = dict(colors = random_colors(20)) 
        layout = go.Layout(barmode='group')
        for g in datacolumns.index.levels[1]:
            gforsats = datacolumns.xs(g, level=1, drop_level=False)
            data.append(go.Bar(
                x= datacolumns.index.levels[0],
                y= gforsats.values,
                name = g))
            
    elif type_of_graph == 'stack':
        data = []
        marker = dict(colors = random_colors(20)) 
        layout = go.Layout(barmode='stack')
        for g in datacolumns.index.levels[1]:
            gforsats = datacolumns.xs(g, level=1, drop_level=False)
            data.append(go.Bar(
                x= datacolumns.index.levels[0],
                y= gforsats.values,
                name = g))    

    elif type_of_graph == 'pie':
        data = [go.Pie(
            labels = data_frame.index,
            values = data_frame.values,
            marker = dict(colors = random_colors(20)),
            textfont = dict(size = 20)
        )]
        
    layout.title = title  
    fig = go.Figure(data = data, layout = layout)
    py.iplot(fig)
    
def bubble_chart(col):
    data = get_list(df[col].dropna())
    data = data[:10]
    data = data.reindex(index=data.index[::-1])

    size = np.array(data[1]*0.001)
    size
    trace0 = go.Scatter(
        x=data[0],
        y=data[1],
        mode='markers',
        marker=dict(color = random_colors(10),size= size)
    )

    data = [trace0]
    py.iplot(data)

# %%
surveydf = pd.read_csv("survey_results_public.csv", low_memory=False)
surveydf["JobSatisfaction"].head(10)
# Out:
# 0                   Extremely satisfied
# 1               Moderately dissatisfied
# 2                  Moderately satisfied
# 3    Neither satisfied nor dissatisfied
# 4                    Slightly satisfied
# 5                  Moderately satisfied
# 6                    Slightly satisfied
# 7                    Slightly satisfied
# 8                  Moderately satisfied
# 9                                   NaN
# Name: JobSatisfaction, dtype: object

# %%
graph(surveydf["JobSatisfaction"],"pie", title="Percentage of respondents by their levels of job satisfaction")
# Out:
# <div id="79481126-6f57-4f65-a119-5ac9b7aeb8c9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("79481126-6f57-4f65-a119-5ac9b7aeb8c9", [{"labels": ["Moderately satisfied", "Extremely satisfied", "Slightly satisfied", "Slightly dissatisfied", "Moderately dissatisfied", "Neither satisfied nor dissatisfied", "Extremely dissatisfied"], "marker": {"colors": ["#86A19F", "#918C42", "#D46905", "#055C67", "#27B184", "#975ABC", "#B742BC", "#729DD3", "#A888D8", "#7ED91A", "#5B50ED", "#686881", "#9D21B3", "#F2FA24", "#773796", "#041ECE", "#9AE078", "#D68217", "#EB4CE2", "#5EB143"]}, "textfont": {"size": 20}, "values": [26005, 12436, 10012, 7057, 6318, 4966, 2482], "type": "pie", "uid": "a3d4dfdc-4101-4d33-805e-ac052c1034ef"}], {"title": "Percentage of respondents by their levels of job satisfaction"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("79481126-6f57-4f65-a119-5ac9b7aeb8c9"));});</script>

# %%
satsorter = ['Extremely dissatisfied','Moderately dissatisfied','Slightly dissatisfied','Neither satisfied nor dissatisfied',
             'Slightly satisfied','Moderately satisfied','Extremely satisfied']

agesorter = ['Under 18 years old','18 - 24 years old','25 - 34 years old', '35 - 44 years old','45 - 54 years old', '55 - 64 years old',
             '65 years or older']

lastjobsorter = ["I've never had a job",'Less than a year ago','Between 1 and 2 years ago', 
                 'Between 2 and 4 years ago', 'More than 4 years ago']

companysizesorter = ['Fewer than 10 employees','10 to 19 employees','20 to 99 employees','100 to 499 employees', 
                     '500 to 999 employees', '1,000 to 4,999 employees','5,000 to 9,999 employees',
                     '10,000 or more employees']

merged = get_merged_catColumns(surveydf, "Age", "JobSatisfaction", "Respondent", col1sorter = agesorter, col2sorter=satsorter)
graph(merged,"group", title = "Job Satisfaction for different age groups")

merged = get_merged_catColumns(surveydf, "Employment", "JobSatisfaction", "Respondent", col1sorter = None, col2sorter=satsorter)
graph(merged,"group", title = "Job Satisfaction for different types of employment")

merged = get_merged_catColumns(surveydf, "LastNewJob", "JobSatisfaction", "Respondent", col1sorter = lastjobsorter, col2sorter=satsorter)
graph(merged,"group")

merged = get_merged_catColumns(surveydf, "CompanySize", "JobSatisfaction", "Respondent", col1sorter = companysizesorter, col2sorter=satsorter)
graph(merged,"group", title = "Job Satisfaction per company size")

merged = get_merged_catColumns(surveydf, "EthicsChoice", "JobSatisfaction", "Respondent", col1sorter = None, col2sorter=satsorter)
graph(merged,"group")
# Out:
# <div id="91ddfaaa-5ff7-421c-bc30-486fd8dd8468" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e94a9fb5-fb6f-4a1d-9fb1-23a315e0d4d6", [{"name": "Extremely dissatisfied", "x": ["Employed full-time", "Employed part-time", "Independent contractor, freelancer, or self-employed"], "y": [3.608682908326006, 2.797202797202797, 3.7703399920624423], "type": "bar", "uid": "426e02c8-b56c-4148-aebe-1f2526fa02dd"}, {"name": "Moderately dissatisfied", "x": ["Employed full-time", "Employed part-time", "Independent contractor, freelancer, or self-employed"], "y": [9.536371316746841, 8.122646584185047, 6.4161926180711735], "type": "bar", "uid": "300af685-bf42-461b-8aaa-489a72a64b32"}, {"name": "Slightly dissatisfied", "x": ["Employed full-time", "Employed part-time", "Independent contractor, freelancer, or self-employed"], "y": [10.39500681046225, 10.274341043571813, 8.546103982008201], "type": "bar", "uid": "e8256b81-cae8-42d6-ba2f-3fd7b6ef91d1"}, {"name": "Neither satisfied nor dissatisfied", "x": ["Employed full-time", "Employed part-time", "Independent contractor, freelancer, or self-employed"], "y": [6.634597148226693, 8.902635825712748, 10.411430083344356], "type": "bar", "uid": "eea92cbc-f067-4162-bcdf-10132a8fe479"}, {"name": "Slightly satisfied", "x": ["Employed full-time", "Employed part-time", "Independent contractor, freelancer, or self-employed"], "y": [14.469214986465284, 16.4873587950511, 13.321867971953964], "type": "bar", "uid": "6e81927e-78f5-4f64-b9a2-2853536e4f83"}, {"name": "Moderately satisfied", "x": ["Employed full-time", "Employed part-time", "Independent contractor, freelancer, or self-employed"], "y": [37.82823841790376, 37.70844540075309, 35.22952771530626], "type": "bar", "uid": "3faabaf2-3fb9-44ee-9934-cc0153709e7f"}, {"name": "Extremely satisfied", "x": ["Employed full-time", "Employed part-time", "Independent contractor, freelancer, or self-employed"], "y": [17.52788841186917, 15.707369553523401, 22.304537637253606], "type": "bar", "uid": "3fe803d1-3927-43fd-9fd4-c29306d7f165"}], {"barmode": "group", "title": "Job Satisfaction for different types of employment"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("e94a9fb5-fb6f-4a1d-9fb1-23a315e0d4d6"));});</script>
# <div id="0b58ef0a-17ea-4bc3-93fd-ec8766a504b2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0b58ef0a-17ea-4bc3-93fd-ec8766a504b2", [{"name": "Extremely dissatisfied", "x": ["I've never had a job", "Less than a year ago", "Between 1 and 2 years ago", "Between 2 and 4 years ago", "More than 4 years ago"], "y": [3.951367781155015, 3.4765833435947955, 3.6238675413933144, 3.4004410613929004, 3.9116494478090487], "type": "bar", "uid": "f7d9a226-852d-4944-847b-68f17e9019a7"}, {"name": "Moderately dissatisfied", "x": ["I've never had a job", "Less than a year ago", "Between 1 and 2 years ago", "Between 2 and 4 years ago", "More than 4 years ago"], "y": [4.86322188449848, 7.811024914829864, 9.79693845673227, 10.137298143273814, 9.640185251157819], "type": "bar", "uid": "167e6b4f-8f59-46bd-8da0-9e98f297459f"}, {"name": "Slightly dissatisfied", "x": ["I've never had a job", "Less than a year ago", "Between 1 and 2 years ago", "Between 2 and 4 years ago", "More than 4 years ago"], "y": [6.68693009118541, 8.500595164799082, 10.815370196813495, 11.702354698726614, 10.9939437121482], "type": "bar", "uid": "4a6e5ce6-d9a2-489e-af87-e88783ac464d"}, {"name": "Neither satisfied nor dissatisfied", "x": ["I've never had a job", "Less than a year ago", "Between 1 and 2 years ago", "Between 2 and 4 years ago", "More than 4 years ago"], "y": [19.756838905775076, 7.5319131469851825, 7.278975320212433, 6.615920893505016, 6.5265407908799435], "type": "bar", "uid": "ec3417ff-82dd-4c8e-87b1-a2dc40f63cdd"}, {"name": "Slightly satisfied", "x": ["I've never had a job", "Less than a year ago", "Between 1 and 2 years ago", "Between 2 and 4 years ago", "More than 4 years ago"], "y": [14.893617021276595, 14.325001026146206, 15.413933145891908, 14.661734367219179, 13.395083719273245], "type": "bar", "uid": "da6c2de3-7861-4c7a-a477-7f23929d4e62"}, {"name": "Moderately satisfied", "x": ["I've never had a job", "Less than a year ago", "Between 1 and 2 years ago", "Between 2 and 4 years ago", "More than 4 years ago"], "y": [28.57142857142857, 38.09465172597792, 36.932208684786005, 37.21277655260724, 37.862486640541505], "type": "bar", "uid": "cc2a5c12-7bf5-4382-b959-de49a548774f"}, {"name": "Extremely satisfied", "x": ["I've never had a job", "Less than a year ago", "Between 1 and 2 years ago", "Between 2 and 4 years ago", "More than 4 years ago"], "y": [21.27659574468085, 20.260230677666954, 16.13870665417057, 16.269474283275237, 17.67011043819024], "type": "bar", "uid": "2c79ec23-1876-4f71-ad2b-73c4c2411456"}], {"barmode": "group"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("0b58ef0a-17ea-4bc3-93fd-ec8766a504b2"));});</script>
# <div id="89b87780-35c7-4207-8cc8-f2e580a98a1a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("89b87780-35c7-4207-8cc8-f2e580a98a1a", [{"name": "Extremely dissatisfied", "x": ["Fewer than 10 employees", "10 to 19 employees", "20 to 99 employees", "100 to 499 employees", "500 to 999 employees", "1,000 to 4,999 employees", "5,000 to 9,999 employees", "10,000 or more employees"], "y": [4.66013176924313, 3.481392557022809, 3.3153377630121814, 3.1118587047939443, 3.964984552008239, 3.037817730936144, 2.9341792228390164, 4.097171863669326], "type": "bar", "uid": "0c948a5f-0c95-494a-ac24-5dc55c51b061"}, {"name": "Moderately dissatisfied", "x": ["Fewer than 10 employees", "10 to 19 employees", "20 to 99 employees", "100 to 499 employees", "500 to 999 employees", "1,000 to 4,999 employees", "5,000 to 9,999 employees", "10,000 or more employees"], "y": [9.014944560501366, 9.423769507803122, 9.392303433001107, 9.2094196804037, 9.86096807415036, 9.314941103533787, 9.754163362410786, 10.297316896301668], "type": "bar", "uid": "f9ebae41-050c-40a4-aa0f-25e136896d0b"}, {"name": "Slightly dissatisfied", "x": ["Fewer than 10 employees", "10 to 19 employees", "20 to 99 employees", "100 to 499 employees", "500 to 999 employees", "1,000 to 4,999 employees", "5,000 to 9,999 employees", "10,000 or more employees"], "y": [9.127430499758958, 10.264105642256903, 10.361295681063124, 10.210260723296887, 9.680741503604532, 11.035337879727217, 10.785091197462332, 11.481750060430263], "type": "bar", "uid": "37824774-ba0d-4f13-90ba-1f173c055a73"}, {"name": "Neither satisfied nor dissatisfied", "x": ["Fewer than 10 employees", "10 to 19 employees", "20 to 99 employees", "100 to 499 employees", "500 to 999 employees", "1,000 to 4,999 employees", "5,000 to 9,999 employees", "10,000 or more employees"], "y": [6.94198939418287, 7.052821128451381, 6.782945736434108, 6.703111858704794, 6.642636457260556, 6.075635461872288, 6.502775574940524, 6.768189509306261], "type": "bar", "uid": "f3645bc8-53c6-4a27-bcf9-4f2fd8aa4c81"}, {"name": "Slightly satisfied", "x": ["Fewer than 10 employees", "10 to 19 employees", "20 to 99 employees", "100 to 499 employees", "500 to 999 employees", "1,000 to 4,999 employees", "5,000 to 9,999 employees", "10,000 or more employees"], "y": [14.028603567411215, 14.315726290516206, 14.735603543743078, 14.676198486122793, 14.958805355303811, 15.034097954122752, 14.432989690721648, 14.358230601885424], "type": "bar", "uid": "a968a459-5a28-4281-aa0b-920655d148e4"}, {"name": "Moderately satisfied", "x": ["Fewer than 10 employees", "10 to 19 employees", "20 to 99 employees", "100 to 499 employees", "500 to 999 employees", "1,000 to 4,999 employees", "5,000 to 9,999 employees", "10,000 or more employees"], "y": [35.722320424232684, 37.064825930372145, 38.12984496124031, 39.1084945332212, 38.15653964984552, 38.49969001859888, 37.82712133227597, 37.249214406574815], "type": "bar", "uid": "3457e338-463b-499a-a9dd-46491624d684"}, {"name": "Extremely satisfied", "x": ["Fewer than 10 employees", "10 to 19 employees", "20 to 99 employees", "100 to 499 employees", "500 to 999 employees", "1,000 to 4,999 employees", "5,000 to 9,999 employees", "10,000 or more employees"], "y": [20.504579784669772, 18.39735894357743, 17.28266888150609, 16.980656013456684, 16.735324407826983, 17.002479851208925, 17.763679619349723, 15.748126661832245], "type": "bar", "uid": "97dea234-b7ab-41f1-8d9e-e1ca429199d0"}], {"barmode": "group", "title": "Job Satisfaction per company size"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("89b87780-35c7-4207-8cc8-f2e580a98a1a"));});</script>
# <div id="00e845ac-62ca-41c9-9ae4-2c818133df6d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("00e845ac-62ca-41c9-9ae4-2c818133df6d", [{"name": "Extremely dissatisfied", "x": ["Depends on what it is", "No", "Yes"], "y": [2.957314237887101, 3.4942373263448587, 6.851851851851852], "type": "bar", "uid": "faee674e-d755-46d2-a947-9be47eb87e0c"}, {"name": "Moderately dissatisfied", "x": ["Depends on what it is", "No", "Yes"], "y": [8.909141634892588, 9.3442669146448, 9.555555555555555], "type": "bar", "uid": "3abc3689-6f4b-4e8c-a664-614541b4ff5f"}, {"name": "Slightly dissatisfied", "x": ["Depends on what it is", "No", "Yes"], "y": [10.99228122384451, 9.673965113985403, 11.481481481481481], "type": "bar", "uid": "3047d768-e5e5-4913-b6fd-f77f8f6dfe20"}, {"name": "Neither satisfied nor dissatisfied", "x": ["Depends on what it is", "No", "Yes"], "y": [7.997768064726123, 5.957111054752445, 9.777777777777779], "type": "bar", "uid": "5aa18026-d0c7-4dc0-b850-440290b68bef"}, {"name": "Slightly satisfied", "x": ["Depends on what it is", "No", "Yes"], "y": [16.0187854552218, 13.207653506918026, 16.666666666666664], "type": "bar", "uid": "d45999b5-fe45-4fd9-831a-1a1c6ada7b6b"}, {"name": "Moderately satisfied", "x": ["Depends on what it is", "No", "Yes"], "y": [37.84990235283176, 38.09845859046975, 30.25925925925926], "type": "bar", "uid": "e82bd132-45fc-47cd-b450-d1b7cd23ff15"}, {"name": "Extremely satisfied", "x": ["Depends on what it is", "No", "Yes"], "y": [15.274807030596113, 20.22430749288472, 15.407407407407408], "type": "bar", "uid": "e2d8d0de-2e10-46ec-b532-c9c726955f35"}], {"barmode": "group"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("00e845ac-62ca-41c9-9ae4-2c818133df6d"));});</script>

# %%
gp = surveydf.groupby("JobSatisfaction")["ConvertedSalary"].median()
graph(gp,"gpbarv",title = "Median salary by levels of job satisfaction")
# Out:
# <div id="682cd4da-0739-4068-a267-7fef04292837" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("682cd4da-0739-4068-a267-7fef04292837", [{"marker": {"color": ["#8A2CB1", "#3800DD", "#865B96", "#B14A8D", "#312553", "#7C915F", "#5728D6", "#56403C", "#ED6E3D", "#EBF0E7"], "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "opacity": 0.6, "x": ["Extremely dissatisfied", "Extremely satisfied", "Moderately dissatisfied", "Moderately satisfied", "Neither satisfied nor dissatisfied", "Slightly dissatisfied", "Slightly satisfied"], "y": [52563.5, 71976.0, 55075.0, 59729.0, 42456.0, 50000.0, 47688.0], "type": "bar", "uid": "99245925-c6bf-4077-a090-910005594242"}], {"title": "Median salary by levels of job satisfaction"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("682cd4da-0739-4068-a267-7fef04292837"));});</script>

# %%
Jobsat_Encoding = { 'Extremely dissatisfied' : 1,
                    'Moderately dissatisfied' : 5,
                    'Slightly dissatisfied':8,
                    'Neither satisfied nor dissatisfied':11,
                    'Slightly satisfied':14,
                    'Moderately satisfied' : 17,
                    'Extremely satisfied' : 21,
                     }

countries = surveydf[surveydf["JobSatisfaction"].notnull()][['Country','JobSatisfaction']]
countries["JobSatisfaction"] = countries["JobSatisfaction"].apply(lambda x: Jobsat_Encoding[x])
countries = countries.groupby("Country")["JobSatisfaction"].agg(['mean']).reset_index()


countries.loc[2]['code'] = ''
for i,country in enumerate(countries['Country']):
    user_input = country
    mapping = {country.name: country.alpha_3 for country in pycountry.countries}
    countries.set_value(i, 'code', mapping.get(user_input))
data = [ dict(
        type = 'choropleth',
        locations = countries['code'],
        z = countries['mean'],
        text = countries['Country'],
        autocolorscale = True,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            title = 'Job Satisfaction Degree'),
      ) ]

layout = dict(
    title = 'Average Satisfaction Degree',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False)
# Out:
# C:\Users\Bahar\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Bahar\Anaconda3\lib\site-packages\pandas\core\series.py:914: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Bahar\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning:
#
# set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# <div id="2aafd369-4ecd-4994-a54e-a7e231a5771d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
.18, 12.0, 11.529411764705882, 12.5, 1.0, 13.423529411764706, 15.159090909090908, 14.447941888619855, 14.31578947368421, 14.0, 12.854460093896714, 15.443678160919541, 11.5, 14.26, 14.188180404354588, 12.04, 11.4, 13.069444444444445, 13.805194805194805, 14.327450980392157, 14.44702842377261, 12.8, 13.56, 14.166666666666666, 14.09322033898305, 13.90203426124197, 11.555555555555555, 11.0, 17.0, 12.342465753424657, 15.428571428571429, 14.813229571984436, 17.0, 13.91025641025641, 14.111731843575418, 14.577380952380953, 17.0, 13.285714285714286, 14.826, 13.284210526315789, 13.625194401244167, 13.642857142857142, 9.0, 17.0, 12.5, 15.375560538116591, 15.338481338481339, 13.758620689655173, 11.788617886178862, 19.666666666666668, 13.91869918699187, 13.076923076923077, 16.0, 11.0625, 11.976744186046512, 12.633738601823708, 11.0, 12.305555555555555, 13.767813267813267, 13.152, 14.664681724845996, 15.310344827586206, 14.889393652596379, 14.779 ...

# %%
cc = countries.sort_values(by="mean",ascending = False).reset_index()
cc
# Out:
#      index                      Country       mean  code
# 0       94             Marshall Islands  21.000000   MHL
# 1      149                   Tajikistan  19.666667   TJK
# 2       26                      Burundi  17.000000   BDI
# 3      128                   San Marino  17.000000   SMR
# 4      143                     Suriname  17.000000   SUR
# 5        4                       Angola  17.000000   AGO
# 6      136              Solomon Islands  17.000000   SLB
# 7      132                 Sierra Leone  17.000000   SLE
# 8       50                         Fiji  16.666667   FJI
# 9        3                      Andorra  16.333333   AND
# 10     152                         Togo  16.000000   TGO
# 11      38                       Cyprus  15.515152   CYP
# 12      71                         Iraq  15.500000   IRQ
# 13      99                   Montenegro  15.444444   MNE
# 14     111                       Norway  15.443678   NOR
# 15     130                      Senegal  15.428571   SEN
# 16     168                       Zambia  15.400000   ZMB
# 17      51                      Finland  15.397436   FIN
# 18      42                      Denmark  15.382294   DNK
# 19     145                       Sweden  15.375561   SWE
# 20     146                  Switzerland  15.338481   CHE
# 21      97                       Monaco  15.333333   MCO
# 22     161  United Republic of Tanzania  15.310345  None
# 23      93                        Malta  15.245283   MLT
# 24      95                    Mauritius  15.235294   MUS
# 25     106                  Netherlands  15.159091   NLD
# 26       9                      Austria  15.018868   AUT
# 27     162                United States  14.889394   USA
# 28       7                      Armenia  14.853333   ARM
# 29      16                      Belgium  14.849091   BEL
# ..     ...                          ...        ...   ...
# 140    148                       Taiwan  11.788618  None
# 141     19                       Bhutan  11.666667   BTN
# 142    126                       Rwanda  11.555556   RWA
# 143    102                      Myanmar  11.529412   MMR
# 144    112                         Oman  11.500000   OMN
# 145    116                     Paraguay  11.400000   PRY
# 146     32                        China  11.323829   CHN
# 147    153          Trinidad and Tobago  11.062500   TTO
# 148    156                 Turkmenistan  11.000000   TKM
# 149     61                       Guinea  11.000000   GIN
# 150    127                  Saint Lucia  11.000000   LCA
# 151     40                Côte d'Ivoire  11.000000   CIV
# 152     37                         Cuba  10.978723   CUB
# 153      0                  Afghanistan  10.736842   AFG
# 154     85       Libyan Arab Jamahiriya  10.500000  None
# 155     90                       Malawi  10.000000   MWI
# 156     34    Congo, Republic of the...  10.000000  None
# 157    142                        Sudan   9.000000   SDN
# 158     22                     Botswana   9.000000   BWA
# 159     75                      Jamaica   8.636364   JAM
# 160     59                      Grenada   8.000000   GRD
# 161     30     Central African Republic   8.000000   CAF
# 162     17                       Belize   8.000000   BLZ
# 163     11                      Bahamas   8.000000   BHS
# 164      5          Antigua and Barbuda   6.500000   ATG
# 165     84                      Lesotho   6.000000   LSO
# 166     62                       Guyana   5.000000   GUY
# 167    104                        Nauru   1.000000   NRU
# 168     43                     Dominica   1.000000   DMA
# 169     25                 Burkina Faso   1.000000   BFA
#
# [170 rows x 4 columns]

# %%
Jobsat_Encoding = {'Extremely dissatisfied' : 1,
                    'Moderately dissatisfied' : 5,
                    'Slightly dissatisfied':8,
                    'Neither satisfied nor dissatisfied':11,
                    'Slightly satisfied':14,
                    'Moderately satisfied' : 17,
                    'Extremely satisfied' : 21,
                     }
yearcCoding_Encoding = {'3-5 years':2, '30 or more years':11, '24-26 years':9, '18-20 years':7,
       '6-8 years':3, '9-11 years':4, '0-2 years':1, '15-17 years':6,
       '12-14 years':5, '21-23 years':8, '27-29 years':10 }

skipMealsDict = {'Never':0, '3 - 4 times per week':3.5, '1 - 2 times per week':1.5,
       'Daily or almost every day':7}

companySizedict = {'20 to 99 employees':3, '10,000 or more employees':15000,
       '100 to 499 employees':300, '10 to 19 employees':15,
       '500 to 999 employees':750, '1,000 to 4,999 employees':3000,
       '5,000 to 9,999 employees':7500, 'Fewer than 10 employees':5}

layout = go.Layout(
                    scene = dict(
                    xaxis = dict(
                        ticktext= list(yearcCoding_Encoding.keys()),
                        tickvals= list(yearcCoding_Encoding.values()),
                        ticks='outside'),
                    yaxis = dict(
                        ticktext= list(Jobsat_Encoding.keys()),
                        tickvals= list(Jobsat_Encoding.values()),
                        ticks='outside')
                    ),
                    margin=dict(
                    r=15, l=15,
                    b=10, t=10)
                )


df = surveydf[(surveydf["CurrencySymbol"] == "USD") & (surveydf["ConvertedSalary"] <800000)][["ConvertedSalary","YearsCoding","JobSatisfaction","CareerSatisfaction","CompanySize"]].dropna()
df["jsNumber"] = df["JobSatisfaction"].apply(lambda x: Jobsat_Encoding[x])


trace1 = go.Scatter3d(
    x=df["YearsCoding"].values,
    y=df["jsNumber"].values,
    z=df["ConvertedSalary"].values,
    mode='markers',
    marker=dict(
        size=4,
        color=df["jsNumber"].values * 2,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)

fig2 = go.Figure(data=[trace1], layout=layout)
py.iplot(fig2)
# Out:
# <div id="633dc3ba-3955-4b37-ba63-dedd215cb94d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
, 34, 34, 42, 22, 34, 16, 42, 42, 16, 42, 2, 34, 34, 34, 34, 28, 28, 10, 42, 42, 28, 34, 42, 2, 42, 34, 42, 22, 28, 34, 16, 28, 34, 42, 10, 16, 34, 28, 42, 42, 22, 34, 28, 34, 34, 10, 28, 42, 16, 42, 10, 34, 2, 16, 34, 10, 42, 34, 34, 42, 10, 42, 42, 34, 28, 34, 42, 34, 42, 34, 34, 34, 10, 10, 34, 34, 42, 28, 28, 34, 34, 34, 28, 34, 28, 42, 10, 10, 34, 16, 34, 42, 42, 10, 22, 34, 34, 16, 42, 34, 34, 34, 34, 34, 34, 34, 42, 42, 34, 34, 10, 34, 42, 16, 28, 34, 42, 42, 22, 28, 10, 2, 2, 28, 16, 34, 10, 28, 42, 42, 42, 34, 34, 34, 34, 10, 42, 34, 28, 42, 34, 28, 34, 34, 34, 16, 42, 10, 34, 10, 34, 34, 42, 22, 16, 28, 34, 28, 34, 42, 34, 34, 16, 28, 34, 42, 34, 34, 42, 34, 34, 34, 42, 10, 10, 28, 22, 34, 42, 34, 16, 2, 34, 34, 34, 16, 34, 34, 28, 10, 34, 42, 34, 28, 2, 42, 42, 28, 10, 10, 42, 28, 34, 42, 34, 34, 34, 42, 34, 16, 10, 16, 34, 42, 34, 42, 34, 42, 34, 16, 34, 16, 16, 16, 34, 42, 10, 28, 42, 34, 10, 34, 10, 22, 34, 28, 34, 10, 16, 22, 42, 34, 34, 34, 34, 34, 42, 16, 34, 34, 42, 34, 34, 34, 42, 22, 34, 34, 34, 34, 34, 34, 10, 34, 28, 2, 34, 34, 42, 28, 22, 34, 34, 34, 34, 42, 16, 34, 34, 34, 22, 42, 28, 42, 16, 42, 42, 42, 28, 42, 42, 28, 34, 34, 34, 42, 16, 34, 34, 34, 34, 28, 28, 34, 34, 34, 34, 28, 42, 16, 22, 34, 42, 34, 42, 10, 34, 16, 34, 28, 42, 28, 42, 34, 34, 10, 34, 28, 42, 28, 2, 2, 34, 42, 28, 28, 10, 2, 10, 42, 34, 28, 34, 16, 34, 28, 16, 42, 16, 34, 34, 34, 42, 42, 34, 34, 34, 34, 10, 34, 10, 34, 28, 10, 10, 42, 34, 34, 16, 42, ...

# %%
import itertools 
devtypes = surveydf[surveydf['PlatformWorkedWith'].notnull()]['PlatformWorkedWith'].apply(lambda x: x.split(";"))
devtypeslist = list(set(itertools.chain(*devtypes)))

for t in devtypeslist:
    print(t)
    graph(surveydf[(surveydf["FrameworkWorkedWith"].notnull()) & (surveydf["FrameworkWorkedWith"].str.contains(t))]["JobSatisfaction"],"pie")

# %%
import plotly.figure_factory as ff

satisfaction_levels = ['Extremely dissatisfied' ,
                    'Moderately dissatisfied',
                    'Slightly dissatisfied',
                    'Neither satisfied nor dissatisfied',
                    'Slightly satisfied',
                    'Moderately satisfied',
                    'Extremely satisfied'
     ]


tups = dict({})
for j in satisfaction_levels:
    for c in satisfaction_levels:
        tups[(j,c)] = df[(df["JobSatisfaction"] == j) & (df["CareerSatisfaction"] == c)]["JobSatisfaction"].count()
        
zcolors=[list(tups.values())[(i*7):(i+1)*7] for i in range(0,7)]
fig = ff.create_annotated_heatmap(showscale=True, z = (zcolors),x=list(satisfaction_levels),y=list(satisfaction_levels), colorscale='Viridis')

fig.layout.xaxis = dict(
        title='Career Satisfaction',
        automargin = True
    )
fig.layout.yaxis = dict(
        title='Job Satisfaction',
        automargin = True
    )
fig.layout.title = "Heatmap for the relationship between job and career satisfaction"
py.iplot(fig)
# Out:
# <div id="d6181d2e-5469-4a9a-81b7-dd037fa08aa2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d6181d2e-5469-4a9a-81b7-dd037fa08aa2", [{"colorscale": "Viridis", "reversescale": false, "showscale": true, "x": ["Extremely dissatisfied", "Moderately dissatisfied", "Slightly dissatisfied", "Neither satisfied nor dissatisfied", "Slightly satisfied", "Moderately satisfied", "Extremely satisfied"], "y": ["Extremely dissatisfied", "Moderately dissatisfied", "Slightly dissatisfied", "Neither satisfied nor dissatisfied", "Slightly satisfied", "Moderately satisfied", "Extremely satisfied"], "z": [[118, 91, 37, 13, 37, 67, 34], [93, 275, 196, 78, 205, 266, 84], [31, 110, 244, 114, 243, 361, 92], [11, 27, 95, 130, 152, 158, 44], [18, 51, 135, 110, 481, 661, 159], [21, 52, 142, 101, 666, 2686, 1190], [16, 26, 20, 8, 124, 995, 1646]], "type": "heatmap", "uid": "af1edcb6-5ea7-45aa-b3f8-854cb3072d59"}], {"annotations": [{"font": {"color": "#000000"}, "showarrow": false, "text": "118", "x": "Extremely dissatisfied", "xref": "x", "y": "Extremely dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "91", "x": "Moderately dissatisfied", "xref": "x", "y": "Extremely dissatisfied", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "37", "x": "Slightly dissatisfied", "xref": "x", "y": "Extremely dissatisfied", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "13", "x": "Neither satisfied nor dissatisfied", "xref": "x", "y": "Extremely dissatisfied", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "37", "x": "Slightly satisfied", "xref": "x", "y": "Extremely dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "67", "x": "Moderately satisfied", "xref": "x", "y": "Extremely dissatisfied", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "34", "x": "Extremely satisfied", "xref": "x", "y": "Extremely dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "93", "x": "Extremely dissatisfied", "xref": "x", "y": "Moderately dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "275", "x": "Moderately dissatisfied", "xref": "x", "y": "Moderately dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "196", "x": "Slightly dissatisfied", "xref": "x", "y": "Moderately dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "78", "x": "Neither satisfied nor dissatisfied", "xref": "x", "y": "Moderately dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "205", "x": "Slightly satisfied", "xref": "x", "y": "Moderately dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "266", "x": "Moderately satisfied", "xref": "x", "y": "Moderately dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "84", "x": "Extremely satisfied", "xref": "x", "y": "Moderately dissatisfied", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "31", "x": "Extremely dissatisfied", "xref": "x", "y": "Slightly dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "110", "x": "Moderately dissatisfied", "xref": "x", "y": "Slightly dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "244", "x": "Slightly dissatisfied", "xref": "x", "y": "Slightly dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "114", "x": "Neither satisfied nor dissatisfied", "xref": "x", "y": "Slightly dissatisfied", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "243", "x": "Slightly satisfied",  ...
